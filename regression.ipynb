# %%
import json
import logging
import warnings
import kagglehub
import pandas as pd
import statsmodels.formula.api as smf
from kagglehub import KaggleDatasetAdapter
from sklearn.preprocessing import StandardScaler

warnings.simplefilter("ignore")
logging.getLogger().setLevel(logging.WARNING)


df_companies = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS, "andrewmvd/sp-500-stocks", "sp500_companies.csv"
).drop_duplicates(subset=["Shortname"], keep="first")
companies = df_companies[df_companies["Country"] == "United States"]["Symbol"].values
with open("companies.json", "r", encoding="utf-8") as f:
    data = json.load(f)
missing_companies = [entry["ticker"] for entry in data["missing_companies"]]
companies = [c for c in companies if c not in missing_companies]
search_queries = ["IT capability", "organizational resilience"]
financials_file = "financials.csv"
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.11).

# %%
def rename_columns(df):
    return df.rename(
        columns={
            "IT capability": "IT_similarity",
            "organizational resilience": "OR_similarity",
            "Net Income": "Net_Income",
        }
    )


# 合併資料
def process_data(root):
    global search_queries, financials_file, df_companies

    # 載入 similarity 資料
    df_report_IT = pd.read_csv(root + search_queries[0] + "_report_similarity.csv")
    df_filter_IT = pd.read_csv(root + search_queries[0] + "_filter_similarity.csv")
    df_report_OR = pd.read_csv(root + search_queries[1] + "_report_similarity.csv")
    df_filter_OR = pd.read_csv(root + search_queries[1] + "_filter_similarity.csv")

    # 長格式轉換
    df_report_IT_long = df_report_IT.melt(
        id_vars=["ticker"], var_name="year", value_name="IT_similarity"
    )
    df_filter_IT_long = df_filter_IT.melt(
        id_vars=["ticker"], var_name="year", value_name="IT_similarity"
    )
    df_report_OR_long = df_report_OR.melt(
        id_vars=["ticker"], var_name="year", value_name="OR_similarity"
    )
    df_filter_OR_long = df_filter_OR.melt(
        id_vars=["ticker"], var_name="year", value_name="OR_similarity"
    )

    # 合併 IT 與 OR
    df_report = pd.merge(df_report_IT_long, df_report_OR_long, on=["ticker", "year"])
    df_filter = pd.merge(df_filter_IT_long, df_filter_OR_long, on=["ticker", "year"])
    df_report = df_report.sort_values(["ticker", "year"])
    df_filter = df_filter.sort_values(["ticker", "year"])

    # 計算成長率
    df_report["IT_growth"] = df_report.groupby("ticker")["IT_similarity"].pct_change()
    df_report["OR_growth"] = df_report.groupby("ticker")["OR_similarity"].pct_change()
    df_filter["IT_growth"] = df_filter.groupby("ticker")["IT_similarity"].pct_change()
    df_filter["OR_growth"] = df_filter.groupby("ticker")["OR_similarity"].pct_change()

    # 合併財務資料
    df_financials = pd.read_csv(financials_file)
    df_financials["year"] = df_financials["year"].astype(str)
    df_report = pd.merge(df_report, df_financials, on=["ticker", "year"], how="left")
    df_filter = pd.merge(df_filter, df_financials, on=["ticker", "year"], how="left")

    # 合併公司資料
    df_comp = df_companies[["Symbol", "Sector", "Industry", "Marketcap"]].rename(
        columns={"Symbol": "ticker"}
    )
    df_report = pd.merge(df_report, df_comp, on="ticker", how="left")
    df_filter = pd.merge(df_filter, df_comp, on="ticker", how="left")

    return df_report, df_filter


# 定義迴歸模型函數
def run_regressions(df, label, control=" + C(Sector) + Marketcap"):
    results = {}
    numeric_cols = ["IT_similarity", "OR_similarity", "Net_Income", "Marketcap"]
    df_clean = df.dropna(subset=numeric_cols + ["Sector", "Industry"])
    scaler = StandardScaler()
    df_scaled = df_clean.copy()
    df_scaled[numeric_cols] = scaler.fit_transform(df_scaled[numeric_cols])

    # IT -> OR
    model = smf.ols(f"OR_similarity ~ IT_similarity{control}", data=df_scaled).fit()
    results[f"{label}：IT->OR{control}"] = model

    # IT growth -> OR growth
    model = smf.ols(f"OR_growth ~ IT_growth{control}", data=df_clean).fit()
    results[f"{label}：IT growth -> OR growth{control}"] = model

    # IT -> Revenues
    model = smf.ols(f"Revenues ~ IT_similarity{control}", data=df_scaled).fit()
    results[f"{label}：IT->Revenues{control}"] = model

    # IT -> Net Income
    model = smf.ols(f"Net_Income ~ IT_similarity{control}", data=df_scaled).fit()
    results[f"{label}：IT->Net_Income{control}"] = model

    # OR -> Revenues
    model = smf.ols(f"Revenues ~ OR_similarity{control}", data=df_scaled).fit()
    results[f"{label}：OR->Revenues{control}"] = model

    # OR -> Net Income
    model = smf.ols(f"Net_Income ~ OR_similarity{control}", data=df_scaled).fit()
    results[f"{label}：OR->Net_Income{control}"] = model

    # IT + OR -> Revenues
    model_IT_OR_Net_Income = smf.ols(
        f"Revenues ~ IT_similarity + OR_similarity{control}", data=df_scaled
    ).fit()
    results[f"{label}：IT+OR->Net_Income{control}"] = model_IT_OR_Net_Income

    # IT + OR -> Net Income
    model_IT_OR_Net_Income = smf.ols(
        f"Net_Income ~ IT_similarity + OR_similarity{control}", data=df_scaled
    ).fit()
    results[f"{label}：IT+OR->Net_Income{control}"] = model_IT_OR_Net_Income

    return results


# 定義時間遞移迴歸模型函數
def run_lag_regressions(df, label):
    results = {}

    # 建立 IT_similarity 的 lag 變數（t-1 到 t-5）
    df = df[["ticker", "year", "IT_similarity", "OR_similarity"]].copy()
    df = df.rename(columns={"IT_similarity": "IT", "OR_similarity": "OR"})
    for lag in range(1, 6):
        df[f"IT_lag{lag}"] = df.groupby("ticker")["IT"].shift(lag)

    # 執行迴歸：OR ~ IT_lag{t-lag}
    for lag in range(1, 6):
        col = f"IT_lag{lag}"
        df_lag = df.dropna(subset=["OR", col])
        model = smf.ols(formula=f"OR ~ {col}", data=df_lag).fit()
        results[f"{label}_OR~{col}"] = model

    return results


# 定義成長率時間遞移迴歸模型函數
def run_growth_lag_regressions(df, label):
    results = {}

    # 建立 IT_growth 的 lag 變數（t-1 到 t-5）
    for lag in range(1, 6):
        df[f"IT_growth_lag{lag}"] = df.groupby("ticker")["IT_growth"].shift(lag)

    # 執行迴歸：OR_growth_t ~ IT_growth_{t-lag}
    for lag in range(1, 6):
        col = f"IT_growth_lag{lag}"
        df_lag = df.dropna(subset=["OR_growth", col])
        model = smf.ols(formula=f"OR_growth ~ {col}", data=df_lag).fit()
        results[f"{label}_ORgrowth~{col}"] = model

    return results

# %%
df_7_report, df_7_filter = process_data("paper_7/")
df_17_report, df_17_filter = process_data("paper_17/")

# %%
df_7_report.to_csv("report.csv", index=False)
df_7_filter.to_csv("filter.csv", index=False)

# %%
# 迴歸分析
report_7_results = run_regressions(rename_columns(df_7_report), "Item7_report")
filter_7_results = run_regressions(rename_columns(df_7_filter), "Item7_filter")
report_17_results = run_regressions(rename_columns(df_17_report), "Item17_report")
filter_17_results = run_regressions(rename_columns(df_17_filter), "Item17_filter")

# 顯示所有模型的 summary
all_models = {
    **report_7_results,
    **filter_7_results,
    **report_17_results,
    **filter_17_results,
}
model_summaries = {name: model.summary() for name, model in all_models.items()}
model_summaries
# Out:
# {'Item7_report：IT->OR + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:          OR_similarity   R-squared:                       0.497
#  Model:                            OLS   Adj. R-squared:                  0.460
#  Method:                 Least Squares   F-statistic:                     13.51
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.35e-10
#  Time:                        05:10:31   Log-Likelihood:                -95.700
#  No. Observations:                  89   AIC:                             205.4
#  Df Residuals:                      82   BIC:                             222.8
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                          -0.3778      0.172     -2.192      0.031      -0.721      -0.035
#  C(Sector)[T.Consumer Cyclical]      0.6534      0.268      2.437      0.017       0.120       1.187
#  C(Sector)[T.Consumer Defensive]     0.9523      0.342      2.786      0.007       0.272       1.632
#  C(Sector)[T.Financial Services]     1.1427      0.310      3.687      0.000       0.526       1.759
#  C(Sector)[T.Technology]             0.0978      0.253      0.386      0.700      -0.406       0.602
#  IT_similarity                       0.5152      0.091      5.661      0.000       0.334       0.696
#  Marketcap                           0.0337      0.130      0.260      0.796      -0.224       0.292
#  ==============================================================================
#  Omnibus:                        2.863   Durbin-Watson:                   1.266
#  Prob(Omnibus):                  0.239   Jarque-Bera (JB):                2.579
#  Skew:                          -0.417   Prob(JB):                        0.275
#  Kurtosis:                       2.981   Cond. No.                         6.46
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report：IT growth -> OR growth + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.029
#  Model:                            OLS   Adj. R-squared:                 -0.049
#  Method:                 Least Squares   F-statistic:                    0.3687
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):              0.897
#  Time:                        05:10:31   Log-Likelihood:                 27.961
#  No. Observations:                  82   AIC:                            -41.92
#  Df Residuals:                      75   BIC:                            -25.07
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                          -0.0039      0.070     -0.055      0.956      -0.144       0.136
#  C(Sector)[T.Consumer Cyclical]      0.0406      0.066      0.620      0.537      -0.090       0.171
#  C(Sector)[T.Consumer Defensive]    -0.0341      0.081     -0.420      0.676      -0.196       0.128
#  C(Sector)[T.Financial Services]     0.0219      0.079      0.277      0.782      -0.135       0.179
#  C(Sector)[T.Technology]             0.0302      0.062      0.488      0.627      -0.093       0.154
#  IT_growth                           0.0934      0.089      1.054      0.295      -0.083       0.270
#  Marketcap                       -4.911e-15   2.94e-14     -0.167      0.868   -6.34e-14    5.36e-14
#  ==============================================================================
#  Omnibus:                       11.231   Durbin-Watson:                   2.641
#  Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.268
#  Skew:                           0.730   Prob(JB):                      0.00217
#  Kurtosis:                       4.208   Cond. No.                     1.41e+13
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.41e+13. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'Item7_report：IT->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.800
#  Model:                            OLS   Adj. R-squared:                  0.781
#  Method:                 Least Squares   F-statistic:                     42.54
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.69e-20
#  Time:                        05:10:31   Log-Likelihood:                -1881.4
#  No. Observations:                  71   AIC:                             3777.
#  Df Residuals:                      64   BIC:                             3793.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.422e+11    2.1e+10      6.785      0.000       1e+11    1.84e+11
#  C(Sector)[T.Consumer Cyclical]  -1.468e+11   4.04e+10     -3.631      0.001   -2.28e+11    -6.6e+10
#  C(Sector)[T.Consumer Defensive]  4.697e+11   4.21e+10     11.156      0.000    3.86e+11    5.54e+11
#  C(Sector)[T.Financial Services]  2.348e+11   3.72e+10      6.312      0.000    1.61e+11    3.09e+11
#  C(Sector)[T.Technology]         -1.069e+11   3.84e+10     -2.781      0.007   -1.84e+11   -3.01e+10
#  IT_similarity                     3.01e+10   1.11e+10      2.704      0.009    7.86e+09    5.23e+10
#  Marketcap                        9.314e+10   2.17e+10      4.283      0.000    4.97e+10    1.37e+11
#  ==============================================================================
#  Omnibus:                        3.636   Durbin-Watson:                   1.276
#  Prob(Omnibus):                  0.162   Jarque-Bera (JB):                3.012
#  Skew:                           0.497   Prob(JB):                        0.222
#  Kurtosis:                       3.178   Cond. No.                         6.45
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report：IT->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.362
#  Model:                            OLS   Adj. R-squared:                  0.316
#  Method:                 Least Squares   F-statistic:                     7.765
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.26e-06
#  Time:                        05:10:31   Log-Likelihood:                -106.26
#  No. Observations:                  89   AIC:                             226.5
#  Df Residuals:                      82   BIC:                             243.9
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2953      0.194      1.522      0.132      -0.091       0.681
#  C(Sector)[T.Consumer Cyclical]     -1.0859      0.302     -3.597      0.001      -1.686      -0.485
#  C(Sector)[T.Consumer Defensive]    -0.2310      0.385     -0.600      0.550      -0.997       0.535
#  C(Sector)[T.Financial Services]     1.0297      0.349      2.951      0.004       0.336       1.724
#  C(Sector)[T.Technology]            -0.5297      0.285     -1.856      0.067      -1.097       0.038
#  IT_similarity                       0.3197      0.102      3.119      0.003       0.116       0.524
#  Marketcap                           0.5761      0.146      3.945      0.000       0.286       0.867
#  ==============================================================================
#  Omnibus:                        6.733   Durbin-Watson:                   1.836
#  Prob(Omnibus):                  0.035   Jarque-Bera (JB):                7.359
#  Skew:                           0.411   Prob(JB):                       0.0252
#  Kurtosis:                       4.144   Cond. No.                         6.46
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report：OR->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.779
#  Model:                            OLS   Adj. R-squared:                  0.758
#  Method:                 Least Squares   F-statistic:                     37.58
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           3.66e-19
#  Time:                        05:10:31   Log-Likelihood:                -1884.9
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3800.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.314e+11   2.32e+10      5.662      0.000    8.51e+10    1.78e+11
#  C(Sector)[T.Consumer Cyclical]  -1.078e+11    4.7e+10     -2.294      0.025   -2.02e+11   -1.39e+10
#  C(Sector)[T.Consumer Defensive]  5.258e+11   4.59e+10     11.443      0.000    4.34e+11    6.18e+11
#  C(Sector)[T.Financial Services]  2.339e+11   4.05e+10      5.771      0.000    1.53e+11    3.15e+11
#  C(Sector)[T.Technology]          -1.11e+11   4.04e+10     -2.750      0.008   -1.92e+11   -3.04e+10
#  OR_similarity                   -1.098e+10   1.34e+10     -0.822      0.414   -3.77e+10    1.57e+10
#  Marketcap                         9.66e+10   2.28e+10      4.237      0.000    5.11e+10    1.42e+11
#  ==============================================================================
#  Omnibus:                        3.082   Durbin-Watson:                   1.070
#  Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.443
#  Skew:                           0.443   Prob(JB):                        0.295
#  Kurtosis:                       3.199   Cond. No.                         7.93
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report：OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.287
#  Model:                            OLS   Adj. R-squared:                  0.234
#  Method:                 Least Squares   F-statistic:                     5.492
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           8.06e-05
#  Time:                        05:10:31   Log-Likelihood:                -111.25
#  No. Observations:                  89   AIC:                             236.5
#  Df Residuals:                      82   BIC:                             253.9
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2756      0.210      1.311      0.194      -0.143       0.694
#  C(Sector)[T.Consumer Cyclical]     -0.8708      0.330     -2.637      0.010      -1.528      -0.214
#  C(Sector)[T.Consumer Defensive]     0.1863      0.422      0.441      0.660      -0.654       1.026
#  C(Sector)[T.Financial Services]     0.9134      0.383      2.387      0.019       0.152       1.675
#  C(Sector)[T.Technology]            -0.6481      0.299     -2.165      0.033      -1.243      -0.053
#  OR_similarity                       0.0069      0.112      0.061      0.951      -0.215       0.229
#  Marketcap                           0.6464      0.153      4.213      0.000       0.341       0.952
#  ==============================================================================
#  Omnibus:                        3.312   Durbin-Watson:                   1.501
#  Prob(Omnibus):                  0.191   Jarque-Bera (JB):                2.612
#  Skew:                           0.326   Prob(JB):                        0.271
#  Kurtosis:                       3.530   Cond. No.                         7.30
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report：IT+OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.390
#  Model:                            OLS   Adj. R-squared:                  0.337
#  Method:                 Least Squares   F-statistic:                     7.386
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           7.55e-07
#  Time:                        05:10:31   Log-Likelihood:                -104.32
#  No. Observations:                  89   AIC:                             224.6
#  Df Residuals:                      81   BIC:                             244.5
#  Df Model:                           7
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2073      0.197      1.055      0.295      -0.184       0.598
#  C(Sector)[T.Consumer Cyclical]     -0.9336      0.308     -3.033      0.003      -1.546      -0.321
#  C(Sector)[T.Consumer Defensive]    -0.0091      0.396     -0.023      0.982      -0.798       0.780
#  C(Sector)[T.Financial Services]     1.2959      0.371      3.494      0.001       0.558       2.034
#  C(Sector)[T.Technology]            -0.5069      0.281     -1.803      0.075      -1.066       0.053
#  IT_similarity                       0.4397      0.119      3.696      0.000       0.203       0.676
#  OR_similarity                      -0.2330      0.122     -1.903      0.061      -0.477       0.011
#  Marketcap                           0.5839      0.144      4.060      0.000       0.298       0.870
#  ==============================================================================
#  Omnibus:                        8.617   Durbin-Watson:                   2.058
#  Prob(Omnibus):                  0.013   Jarque-Bera (JB):               15.018
#  Skew:                           0.285   Prob(JB):                     0.000548
#  Kurtosis:                       4.930   Cond. No.                         8.06
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：IT->OR + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:          OR_similarity   R-squared:                       0.429
#  Model:                            OLS   Adj. R-squared:                  0.388
#  Method:                 Least Squares   F-statistic:                     10.29
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.80e-08
#  Time:                        05:10:31   Log-Likelihood:                -101.31
#  No. Observations:                  89   AIC:                             216.6
#  Df Residuals:                      82   BIC:                             234.0
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                          -0.1002      0.184     -0.546      0.587      -0.465       0.265
#  C(Sector)[T.Consumer Cyclical]      0.0581      0.278      0.209      0.835      -0.495       0.611
#  C(Sector)[T.Consumer Defensive]     1.3542      0.349      3.876      0.000       0.659       2.049
#  C(Sector)[T.Financial Services]     0.6806      0.328      2.072      0.041       0.027       1.334
#  C(Sector)[T.Technology]            -0.3400      0.268     -1.271      0.207      -0.872       0.192
#  IT_similarity                       0.4428      0.090      4.936      0.000       0.264       0.621
#  Marketcap                           0.3050      0.137      2.229      0.029       0.033       0.577
#  ==============================================================================
#  Omnibus:                        0.466   Durbin-Watson:                   1.401
#  Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.404
#  Skew:                          -0.161   Prob(JB):                        0.817
#  Kurtosis:                       2.925   Cond. No.                         6.56
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：IT growth -> OR growth + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.036
#  Model:                            OLS   Adj. R-squared:                 -0.041
#  Method:                 Least Squares   F-statistic:                    0.4667
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):              0.831
#  Time:                        05:10:31   Log-Likelihood:                -9.2054
#  No. Observations:                  82   AIC:                             32.41
#  Df Residuals:                      75   BIC:                             49.26
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                          -0.0244      0.111     -0.220      0.826      -0.245       0.196
#  C(Sector)[T.Consumer Cyclical]      0.1034      0.103      1.003      0.319      -0.102       0.309
#  C(Sector)[T.Consumer Defensive]    -0.0307      0.128     -0.240      0.811      -0.285       0.224
#  C(Sector)[T.Financial Services]     0.0614      0.124      0.496      0.621      -0.185       0.308
#  C(Sector)[T.Technology]             0.0295      0.097      0.303      0.763      -0.165       0.224
#  IT_growth                           0.1252      0.132      0.949      0.346      -0.138       0.388
#  Marketcap                        9.915e-15   4.62e-14      0.215      0.831   -8.22e-14    1.02e-13
#  ==============================================================================
#  Omnibus:                        1.419   Durbin-Watson:                   2.774
#  Prob(Omnibus):                  0.492   Jarque-Bera (JB):                1.166
#  Skew:                           0.292   Prob(JB):                        0.558
#  Kurtosis:                       2.993   Cond. No.                     1.41e+13
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.41e+13. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'Item7_filter：IT->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.777
#  Model:                            OLS   Adj. R-squared:                  0.756
#  Method:                 Least Squares   F-statistic:                     37.15
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           4.87e-19
#  Time:                        05:10:31   Log-Likelihood:                -1885.2
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3800.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.378e+11    2.2e+10      6.253      0.000    9.38e+10    1.82e+11
#  C(Sector)[T.Consumer Cyclical]  -1.252e+11   4.19e+10     -2.989      0.004   -2.09e+11   -4.15e+10
#  C(Sector)[T.Consumer Defensive]  5.074e+11   4.22e+10     12.020      0.000    4.23e+11    5.92e+11
#  C(Sector)[T.Financial Services]  2.248e+11   3.91e+10      5.756      0.000    1.47e+11    3.03e+11
#  C(Sector)[T.Technology]         -1.138e+11   4.05e+10     -2.808      0.007   -1.95e+11   -3.28e+10
#  IT_similarity                    3.099e+09   1.02e+10      0.304      0.762   -1.73e+10    2.35e+10
#  Marketcap                        9.834e+10    2.3e+10      4.274      0.000    5.24e+10    1.44e+11
#  ==============================================================================
#  Omnibus:                        3.529   Durbin-Watson:                   1.117
#  Prob(Omnibus):                  0.171   Jarque-Bera (JB):                3.163
#  Skew:                           0.517   Prob(JB):                        0.206
#  Kurtosis:                       2.989   Cond. No.                         6.54
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：IT->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.301
#  Model:                            OLS   Adj. R-squared:                  0.250
#  Method:                 Least Squares   F-statistic:                     5.894
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           3.77e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.33
#  No. Observations:                  89   AIC:                             234.7
#  Df Residuals:                      82   BIC:                             252.1
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2836      0.203      1.396      0.167      -0.121       0.688
#  C(Sector)[T.Consumer Cyclical]     -0.8392      0.308     -2.727      0.008      -1.451      -0.227
#  C(Sector)[T.Consumer Defensive]     0.0817      0.387      0.211      0.833      -0.687       0.851
#  C(Sector)[T.Financial Services]     0.9137      0.363      2.514      0.014       0.191       1.637
#  C(Sector)[T.Technology]            -0.6512      0.296     -2.200      0.031      -1.240      -0.062
#  IT_similarity                       0.1303      0.099      1.313      0.193      -0.067       0.328
#  Marketcap                           0.6638      0.151      4.382      0.000       0.363       0.965
#  ==============================================================================
#  Omnibus:                        2.455   Durbin-Watson:                   1.519
#  Prob(Omnibus):                  0.293   Jarque-Bera (JB):                1.866
#  Skew:                           0.199   Prob(JB):                        0.393
#  Kurtosis:                       3.587   Cond. No.                         6.56
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：OR->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.778
#  Model:                            OLS   Adj. R-squared:                  0.757
#  Method:                 Least Squares   F-statistic:                     37.31
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           4.39e-19
#  Time:                        05:10:31   Log-Likelihood:                -1885.1
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3800.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.386e+11   2.21e+10      6.283      0.000    9.45e+10    1.83e+11
#  C(Sector)[T.Consumer Cyclical]  -1.271e+11   4.18e+10     -3.038      0.003   -2.11e+11   -4.35e+10
#  C(Sector)[T.Consumer Defensive]  4.979e+11   4.66e+10     10.693      0.000    4.05e+11    5.91e+11
#  C(Sector)[T.Financial Services]  2.195e+11      4e+10      5.489      0.000     1.4e+11    2.99e+11
#  C(Sector)[T.Technology]         -1.105e+11   4.07e+10     -2.716      0.008   -1.92e+11   -2.92e+10
#  OR_similarity                    6.265e+09   1.14e+10      0.551      0.583   -1.64e+10     2.9e+10
#  Marketcap                        9.558e+10   2.31e+10      4.134      0.000    4.94e+10    1.42e+11
#  ==============================================================================
#  Omnibus:                        3.277   Durbin-Watson:                   1.144
#  Prob(Omnibus):                  0.194   Jarque-Bera (JB):                3.038
#  Skew:                           0.504   Prob(JB):                        0.219
#  Kurtosis:                       2.894   Cond. No.                         7.15
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.293
#  Model:                            OLS   Adj. R-squared:                  0.242
#  Method:                 Least Squares   F-statistic:                     5.670
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           5.76e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.84
#  No. Observations:                  89   AIC:                             235.7
#  Df Residuals:                      82   BIC:                             253.1
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2856      0.205      1.395      0.167      -0.122       0.693
#  C(Sector)[T.Consumer Cyclical]     -0.8615      0.309     -2.789      0.007      -1.476      -0.247
#  C(Sector)[T.Consumer Defensive]     0.0327      0.423      0.077      0.939      -0.809       0.874
#  C(Sector)[T.Financial Services]     0.8539      0.373      2.287      0.025       0.111       1.596
#  C(Sector)[T.Technology]            -0.6174      0.300     -2.059      0.043      -1.214      -0.021
#  OR_similarity                       0.0943      0.108      0.874      0.385      -0.120       0.309
#  Marketcap                           0.6239      0.154      4.046      0.000       0.317       0.931
#  ==============================================================================
#  Omnibus:                        3.110   Durbin-Watson:                   1.575
#  Prob(Omnibus):                  0.211   Jarque-Bera (JB):                2.440
#  Skew:                           0.294   Prob(JB):                        0.295
#  Kurtosis:                       3.558   Cond. No.                         6.82
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter：IT+OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.302
#  Model:                            OLS   Adj. R-squared:                  0.242
#  Method:                 Least Squares   F-statistic:                     5.007
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           9.54e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.28
#  No. Observations:                  89   AIC:                             236.6
#  Df Residuals:                      81   BIC:                             256.5
#  Df Model:                           7
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2871      0.205      1.402      0.165      -0.120       0.694
#  C(Sector)[T.Consumer Cyclical]     -0.8412      0.310     -2.718      0.008      -1.457      -0.225
#  C(Sector)[T.Consumer Defensive]     0.0345      0.423      0.082      0.935      -0.807       0.876
#  C(Sector)[T.Financial Services]     0.8900      0.375      2.374      0.020       0.144       1.636
#  C(Sector)[T.Technology]            -0.6394      0.301     -2.127      0.036      -1.238      -0.041
#  IT_similarity                       0.1149      0.114      1.011      0.315      -0.111       0.341
#  OR_similarity                       0.0348      0.123      0.284      0.778      -0.210       0.279
#  Marketcap                           0.6532      0.157      4.164      0.000       0.341       0.965
#  ==============================================================================
#  Omnibus:                        2.460   Durbin-Watson:                   1.543
#  Prob(Omnibus):                  0.292   Jarque-Bera (JB):                1.866
#  Skew:                           0.202   Prob(JB):                        0.393
#  Kurtosis:                       3.583   Cond. No.                         7.69
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report：IT->OR + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:          OR_similarity   R-squared:                       0.202
#  Model:                            OLS   Adj. R-squared:                  0.144
#  Method:                 Least Squares   F-statistic:                     3.466
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):            0.00420
#  Time:                        05:10:31   Log-Likelihood:                -116.23
#  No. Observations:                  89   AIC:                             246.5
#  Df Residuals:                      82   BIC:                             263.9
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                          -0.5319      0.218     -2.442      0.017      -0.965      -0.099
#  C(Sector)[T.Consumer Cyclical]      0.8534      0.329      2.595      0.011       0.199       1.507
#  C(Sector)[T.Consumer Defensive]     0.5743      0.406      1.414      0.161      -0.234       1.382
#  C(Sector)[T.Financial Services]     1.4017      0.393      3.562      0.001       0.619       2.184
#  C(Sector)[T.Technology]             0.4342      0.321      1.352      0.180      -0.205       1.073
#  IT_similarity                       0.2602      0.105      2.469      0.016       0.051       0.470
#  Marketcap                           0.0062      0.163      0.038      0.970      -0.319       0.331
#  ==============================================================================
#  Omnibus:                        4.232   Durbin-Watson:                   1.968
#  Prob(Omnibus):                  0.121   Jarque-Bera (JB):                3.591
#  Skew:                           0.473   Prob(JB):                        0.166
#  Kurtosis:                       3.269   Cond. No.                         6.30
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report：IT growth -> OR growth + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.008
#  Model:                            OLS   Adj. R-squared:                 -0.072
#  Method:                 Least Squares   F-statistic:                   0.09521
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):              0.997
#  Time:                        05:10:31   Log-Likelihood:                 26.715
#  No. Observations:                  82   AIC:                            -39.43
#  Df Residuals:                      75   BIC:                            -22.58
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.0456      0.071      0.638      0.525      -0.097       0.188
#  C(Sector)[T.Consumer Cyclical]     -0.0100      0.067     -0.150      0.881      -0.142       0.123
#  C(Sector)[T.Consumer Defensive]    -0.0424      0.082     -0.515      0.608      -0.206       0.122
#  C(Sector)[T.Financial Services]    -0.0161      0.080     -0.201      0.841      -0.175       0.143
#  C(Sector)[T.Technology]             0.0213      0.063      0.338      0.736      -0.104       0.146
#  IT_growth                          -0.0235      0.081     -0.291      0.772      -0.184       0.137
#  Marketcap                        -1.11e-14   2.98e-14     -0.372      0.711   -7.05e-14    4.83e-14
#  ==============================================================================
#  Omnibus:                        1.880   Durbin-Watson:                   2.917
#  Prob(Omnibus):                  0.391   Jarque-Bera (JB):                1.624
#  Skew:                           0.344   Prob(JB):                        0.444
#  Kurtosis:                       2.971   Cond. No.                     1.41e+13
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.41e+13. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'Item17_report：IT->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.780
#  Model:                            OLS   Adj. R-squared:                  0.759
#  Method:                 Least Squares   F-statistic:                     37.72
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           3.36e-19
#  Time:                        05:10:31   Log-Likelihood:                -1884.8
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3799.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.362e+11    2.2e+10      6.204      0.000    9.23e+10     1.8e+11
#  C(Sector)[T.Consumer Cyclical]  -1.361e+11   4.31e+10     -3.160      0.002   -2.22e+11   -5.01e+10
#  C(Sector)[T.Consumer Defensive]  5.043e+11   4.18e+10     12.079      0.000    4.21e+11    5.88e+11
#  C(Sector)[T.Financial Services]  2.315e+11   3.95e+10      5.853      0.000    1.52e+11     3.1e+11
#  C(Sector)[T.Technology]         -1.082e+11   4.06e+10     -2.667      0.010   -1.89e+11   -2.72e+10
#  IT_similarity                    1.087e+10   1.18e+10      0.925      0.359   -1.26e+10    3.44e+10
#  Marketcap                        9.585e+10   2.28e+10      4.202      0.000    5.03e+10    1.41e+11
#  ==============================================================================
#  Omnibus:                        4.713   Durbin-Watson:                   1.191
#  Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.053
#  Skew:                           0.574   Prob(JB):                        0.132
#  Kurtosis:                       3.228   Cond. No.                         6.19
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report：IT->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.325
#  Model:                            OLS   Adj. R-squared:                  0.275
#  Method:                 Least Squares   F-statistic:                     6.567
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.08e-05
#  Time:                        05:10:31   Log-Likelihood:                -108.82
#  No. Observations:                  89   AIC:                             231.6
#  Df Residuals:                      82   BIC:                             249.1
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.2335      0.200      1.165      0.247      -0.165       0.632
#  C(Sector)[T.Consumer Cyclical]     -0.9048      0.303     -2.990      0.004      -1.507      -0.303
#  C(Sector)[T.Consumer Defensive]     0.0860      0.374      0.230      0.819      -0.657       0.829
#  C(Sector)[T.Financial Services]     1.0460      0.362      2.889      0.005       0.326       1.766
#  C(Sector)[T.Technology]            -0.5398      0.295     -1.827      0.071      -1.128       0.048
#  IT_similarity                       0.2080      0.097      2.146      0.035       0.015       0.401
#  Marketcap                           0.5956      0.150      3.960      0.000       0.296       0.895
#  ==============================================================================
#  Omnibus:                        4.058   Durbin-Watson:                   1.557
#  Prob(Omnibus):                  0.131   Jarque-Bera (JB):                3.352
#  Skew:                           0.378   Prob(JB):                        0.187
#  Kurtosis:                       3.576   Cond. No.                         6.30
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report：OR->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.780
#  Model:                            OLS   Adj. R-squared:                  0.759
#  Method:                 Least Squares   F-statistic:                     37.74
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           3.32e-19
#  Time:                        05:10:31   Log-Likelihood:                -1884.8
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3799.
# ...
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter：IT growth -> OR growth + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.058
#  Model:                            OLS   Adj. R-squared:                 -0.018
#  Method:                 Least Squares   F-statistic:                    0.7626
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):              0.602
#  Time:                        05:10:31   Log-Likelihood:                 28.730
#  No. Observations:                  82   AIC:                            -43.46
#  Df Residuals:                      75   BIC:                            -26.61
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.0617      0.070      0.885      0.379      -0.077       0.201
#  C(Sector)[T.Consumer Cyclical]      0.0213      0.065      0.327      0.745      -0.108       0.151
#  C(Sector)[T.Consumer Defensive]    -0.0393      0.081     -0.487      0.628      -0.200       0.121
#  C(Sector)[T.Financial Services]    -0.0500      0.078     -0.644      0.522      -0.205       0.105
#  C(Sector)[T.Technology]             0.0022      0.061      0.036      0.971      -0.120       0.124
#  IT_growth                           0.3031      0.170      1.780      0.079      -0.036       0.642
#  Marketcap                       -1.736e-14   2.91e-14     -0.598      0.552   -7.52e-14    4.05e-14
#  ==============================================================================
#  Omnibus:                        8.172   Durbin-Watson:                   2.336
#  Prob(Omnibus):                  0.017   Jarque-Bera (JB):               10.229
#  Skew:                           0.449   Prob(JB):                      0.00601
#  Kurtosis:                       4.479   Cond. No.                     2.07e+13
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 2.07e+13. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'Item17_filter：IT->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.777
#  Model:                            OLS   Adj. R-squared:                  0.756
#  Method:                 Least Squares   F-statistic:                     37.10
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           5.03e-19
#  Time:                        05:10:31   Log-Likelihood:                -1885.2
#  No. Observations:                  71   AIC:                             3784.
#  Df Residuals:                      64   BIC:                             3800.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                        1.399e+11   2.59e+10      5.408      0.000    8.82e+10    1.92e+11
#  C(Sector)[T.Consumer Cyclical]  -1.306e+11   5.13e+10     -2.546      0.013   -2.33e+11   -2.81e+10
#  C(Sector)[T.Consumer Defensive]  5.064e+11   4.58e+10     11.049      0.000    4.15e+11    5.98e+11
#  C(Sector)[T.Financial Services]  2.211e+11   4.41e+10      5.015      0.000    1.33e+11    3.09e+11
#  C(Sector)[T.Technology]         -1.151e+11   4.21e+10     -2.731      0.008   -1.99e+11   -3.09e+10
#  IT_similarity                    2.352e+09   1.44e+10      0.164      0.870   -2.63e+10     3.1e+10
#  Marketcap                        9.747e+10   2.29e+10      4.258      0.000    5.17e+10    1.43e+11
#  ==============================================================================
#  Omnibus:                        3.633   Durbin-Watson:                   1.106
#  Prob(Omnibus):                  0.163   Jarque-Bera (JB):                3.214
#  Skew:                           0.521   Prob(JB):                        0.201
#  Kurtosis:                       3.028   Cond. No.                         8.09
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter：IT->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.293
#  Model:                            OLS   Adj. R-squared:                  0.241
#  Method:                 Least Squares   F-statistic:                     5.653
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           5.95e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.88
#  No. Observations:                  89   AIC:                             235.8
#  Df Residuals:                      82   BIC:                             253.2
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.3548      0.227      1.564      0.122      -0.097       0.806
#  C(Sector)[T.Consumer Cyclical]     -1.0475      0.380     -2.757      0.007      -1.803      -0.292
#  C(Sector)[T.Consumer Defensive]     0.0944      0.399      0.237      0.813      -0.699       0.887
#  C(Sector)[T.Financial Services]     0.8052      0.391      2.060      0.043       0.027       1.583
#  C(Sector)[T.Technology]            -0.7198      0.310     -2.322      0.023      -1.336      -0.103
#  IT_similarity                       0.0972      0.117      0.831      0.408      -0.136       0.330
#  Marketcap                           0.6557      0.152      4.307      0.000       0.353       0.958
#  ==============================================================================
#  Omnibus:                        3.542   Durbin-Watson:                   1.538
#  Prob(Omnibus):                  0.170   Jarque-Bera (JB):                2.822
#  Skew:                           0.355   Prob(JB):                        0.244
#  Kurtosis:                       3.508   Cond. No.                         7.51
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter：OR->Revenues + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:               Revenues   R-squared:                       0.787
#  Model:                            OLS   Adj. R-squared:                  0.767
#  Method:                 Least Squares   F-statistic:                     39.37
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           1.17e-19
#  Time:                        05:10:31   Log-Likelihood:                -1883.6
#  No. Observations:                  71   AIC:                             3781.
#  Df Residuals:                      64   BIC:                             3797.
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                         1.51e+11   2.28e+10      6.611      0.000    1.05e+11    1.97e+11
#  C(Sector)[T.Consumer Cyclical]  -1.441e+11   4.22e+10     -3.414      0.001   -2.28e+11   -5.98e+10
#  C(Sector)[T.Consumer Defensive]  4.729e+11   4.57e+10     10.341      0.000    3.82e+11    5.64e+11
#  C(Sector)[T.Financial Services]  1.793e+11    4.6e+10      3.896      0.000    8.74e+10    2.71e+11
#  C(Sector)[T.Technology]         -1.118e+11   3.96e+10     -2.826      0.006   -1.91e+11   -3.28e+10
#  OR_similarity                    2.136e+10   1.22e+10      1.752      0.084   -2.99e+09    4.57e+10
#  Marketcap                         8.94e+10   2.28e+10      3.914      0.000    4.38e+10    1.35e+11
#  ==============================================================================
#  Omnibus:                        2.290   Durbin-Watson:                   1.326
#  Prob(Omnibus):                  0.318   Jarque-Bera (JB):                1.759
#  Skew:                           0.379   Prob(JB):                        0.415
#  Kurtosis:                       3.138   Cond. No.                         7.95
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter：OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.303
#  Model:                            OLS   Adj. R-squared:                  0.252
#  Method:                 Least Squares   F-statistic:                     5.934
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           3.50e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.24
#  No. Observations:                  89   AIC:                             234.5
#  Df Residuals:                      82   BIC:                             251.9
#  Df Model:                           6
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.3629      0.213      1.703      0.092      -0.061       0.787
#  C(Sector)[T.Consumer Cyclical]     -0.9696      0.316     -3.066      0.003      -1.599      -0.340
#  C(Sector)[T.Consumer Defensive]    -0.0140      0.406     -0.035      0.972      -0.822       0.794
#  C(Sector)[T.Financial Services]     0.6421      0.415      1.546      0.126      -0.184       1.468
#  C(Sector)[T.Technology]            -0.6946      0.298     -2.334      0.022      -1.287      -0.103
#  OR_similarity                       0.1494      0.108      1.377      0.172      -0.066       0.365
#  Marketcap                           0.6216      0.152      4.090      0.000       0.319       0.924
#  ==============================================================================
#  Omnibus:                        3.313   Durbin-Watson:                   1.603
#  Prob(Omnibus):                  0.191   Jarque-Bera (JB):                2.620
#  Skew:                           0.321   Prob(JB):                        0.270
#  Kurtosis:                       3.542   Cond. No.                         7.29
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter：IT+OR->Net_Income + C(Sector) + Marketcap': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:             Net_Income   R-squared:                       0.305
#  Model:                            OLS   Adj. R-squared:                  0.245
#  Method:                 Least Squares   F-statistic:                     5.070
#  Date:                Fri, 18 Apr 2025   Prob (F-statistic):           8.35e-05
#  Time:                        05:10:31   Log-Likelihood:                -110.12
#  No. Observations:                  89   AIC:                             236.2
#  Df Residuals:                      81   BIC:                             256.1
#  Df Model:                           7
#  Covariance Type:            nonrobust
#  ===================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------
#  Intercept                           0.4022      0.230      1.750      0.084      -0.055       0.860
#  C(Sector)[T.Consumer Cyclical]     -1.0669      0.379     -2.813      0.006      -1.822      -0.312
#  C(Sector)[T.Consumer Defensive]    -0.0536      0.417     -0.129      0.898      -0.883       0.776
#  C(Sector)[T.Financial Services]     0.6022      0.426      1.414      0.161      -0.245       1.450
#  C(Sector)[T.Technology]            -0.7318      0.309     -2.366      0.020      -1.347      -0.116
#  IT_similarity                       0.0571      0.122      0.470      0.640      -0.185       0.299
#  OR_similarity                       0.1345      0.113      1.185      0.239      -0.091       0.360
#  Marketcap                           0.6290      0.154      4.097      0.000       0.324       0.934
#  ==============================================================================
#  Omnibus:                        3.483   Durbin-Watson:                   1.614
#  Prob(Omnibus):                  0.175   Jarque-Bera (JB):                2.768
#  Skew:                           0.346   Prob(JB):                        0.251
#  Kurtosis:                       3.517   Cond. No.                         8.51
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """}

# %%
# 時間遞移迴歸
report_7_results = run_lag_regressions(rename_columns(df_7_report), "Item7_report")
filter_7_results = run_lag_regressions(rename_columns(df_7_filter), "Item7_filter")
report_17_results = run_lag_regressions(rename_columns(df_17_report), "Item17_report")
filter_17_results = run_lag_regressions(rename_columns(df_17_filter), "Item17_filter")

# 顯示所有模型的 summary
all_models = {
    **report_7_results,
    **filter_7_results,
    **report_17_results,
    **filter_17_results,
}
model_summaries = {name: model.summary() for name, model in all_models.items()}
model_summaries
# Out:
# {'Item7_report_OR~IT_lag1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.198
#  Model:                            OLS   Adj. R-squared:                  0.189
#  Method:                 Least Squares   F-statistic:                     21.69
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):           1.13e-05
#  Time:                        10:19:54   Log-Likelihood:                 75.467
#  No. Observations:                  90   AIC:                            -146.9
#  Df Residuals:                      88   BIC:                            -141.9
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.3067      0.050      6.139      0.000       0.207       0.406
#  IT_lag1        0.3955      0.085      4.657      0.000       0.227       0.564
#  ==============================================================================
#  Omnibus:                        0.896   Durbin-Watson:                   1.213
#  Prob(Omnibus):                  0.639   Jarque-Bera (JB):                0.888
#  Skew:                           0.043   Prob(JB):                        0.641
#  Kurtosis:                       2.521   Cond. No.                         10.2
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report_OR~IT_lag2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.125
#  Model:                            OLS   Adj. R-squared:                  0.114
#  Method:                 Least Squares   F-statistic:                     11.17
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):            0.00128
#  Time:                        10:19:54   Log-Likelihood:                 68.055
#  No. Observations:                  80   AIC:                            -132.1
#  Df Residuals:                      78   BIC:                            -127.3
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.3619      0.051      7.059      0.000       0.260       0.464
#  IT_lag2        0.2902      0.087      3.342      0.001       0.117       0.463
#  ==============================================================================
#  Omnibus:                        0.504   Durbin-Watson:                   1.243
#  Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.635
#  Skew:                           0.043   Prob(JB):                        0.728
#  Kurtosis:                       2.572   Cond. No.                         9.91
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report_OR~IT_lag3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.092
#  Model:                            OLS   Adj. R-squared:                  0.078
#  Method:                 Least Squares   F-statistic:                     6.851
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0109
#  Time:                        10:19:54   Log-Likelihood:                 65.361
#  No. Observations:                  70   AIC:                            -126.7
#  Df Residuals:                      68   BIC:                            -122.2
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4027      0.049      8.221      0.000       0.305       0.500
#  IT_lag3        0.2154      0.082      2.618      0.011       0.051       0.380
#  ==============================================================================
#  Omnibus:                        1.003   Durbin-Watson:                   1.425
#  Prob(Omnibus):                  0.606   Jarque-Bera (JB):                0.721
#  Skew:                          -0.248   Prob(JB):                        0.697
#  Kurtosis:                       3.024   Cond. No.                         9.56
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report_OR~IT_lag4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.030
#  Model:                            OLS   Adj. R-squared:                  0.013
#  Method:                 Least Squares   F-statistic:                     1.765
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.189
#  Time:                        10:19:54   Log-Likelihood:                 61.583
#  No. Observations:                  60   AIC:                            -119.2
#  Df Residuals:                      58   BIC:                            -115.0
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4579      0.047      9.827      0.000       0.365       0.551
#  IT_lag4        0.1031      0.078      1.328      0.189      -0.052       0.259
#  ==============================================================================
#  Omnibus:                        0.201   Durbin-Watson:                   1.062
#  Prob(Omnibus):                  0.904   Jarque-Bera (JB):                0.391
#  Skew:                           0.077   Prob(JB):                        0.822
#  Kurtosis:                       2.636   Cond. No.                         9.17
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_report_OR~IT_lag5': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.092
#  Model:                            OLS   Adj. R-squared:                  0.074
#  Method:                 Least Squares   F-statistic:                     4.888
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0318
#  Time:                        10:19:54   Log-Likelihood:                 51.976
#  No. Observations:                  50   AIC:                            -99.95
#  Df Residuals:                      48   BIC:                            -96.13
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4071      0.049      8.299      0.000       0.308       0.506
#  IT_lag5        0.1805      0.082      2.211      0.032       0.016       0.345
#  ==============================================================================
#  Omnibus:                        0.354   Durbin-Watson:                   1.357
#  Prob(Omnibus):                  0.838   Jarque-Bera (JB):                0.504
#  Skew:                          -0.164   Prob(JB):                        0.777
#  Kurtosis:                       2.634   Cond. No.                         8.89
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_OR~IT_lag1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.243
#  Model:                            OLS   Adj. R-squared:                  0.235
#  Method:                 Least Squares   F-statistic:                     28.28
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):           7.88e-07
#  Time:                        10:19:54   Log-Likelihood:                 55.395
#  No. Observations:                  90   AIC:                            -106.8
#  Df Residuals:                      88   BIC:                            -101.8
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.1986      0.057      3.464      0.001       0.085       0.313
#  IT_lag1        0.5670      0.107      5.318      0.000       0.355       0.779
#  ==============================================================================
#  Omnibus:                        1.548   Durbin-Watson:                   1.382
#  Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.498
#  Skew:                           0.305   Prob(JB):                        0.473
#  Kurtosis:                       2.837   Cond. No.                         9.76
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_OR~IT_lag2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.221
#  Model:                            OLS   Adj. R-squared:                  0.211
#  Method:                 Least Squares   F-statistic:                     22.19
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):           1.06e-05
#  Time:                        10:19:54   Log-Likelihood:                 52.134
#  No. Observations:                  80   AIC:                            -100.3
#  Df Residuals:                      78   BIC:                            -95.50
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.2338      0.057      4.110      0.000       0.121       0.347
#  IT_lag2        0.4982      0.106      4.710      0.000       0.288       0.709
#  ==============================================================================
#  Omnibus:                        0.513   Durbin-Watson:                   1.221
#  Prob(Omnibus):                  0.774   Jarque-Bera (JB):                0.360
#  Skew:                           0.164   Prob(JB):                        0.835
#  Kurtosis:                       2.983   Cond. No.                         9.44
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_OR~IT_lag3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.044
#  Model:                            OLS   Adj. R-squared:                  0.030
#  Method:                 Least Squares   F-statistic:                     3.126
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0815
#  Time:                        10:19:54   Log-Likelihood:                 44.669
#  No. Observations:                  70   AIC:                            -85.34
#  Df Residuals:                      68   BIC:                            -80.84
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.3846      0.061      6.293      0.000       0.263       0.507
#  IT_lag3        0.2021      0.114      1.768      0.082      -0.026       0.430
#  ==============================================================================
#  Omnibus:                        8.750   Durbin-Watson:                   1.401
#  Prob(Omnibus):                  0.013   Jarque-Bera (JB):                9.162
#  Skew:                           0.625   Prob(JB):                       0.0102
#  Kurtosis:                       4.257   Cond. No.                         9.38
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_OR~IT_lag4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.009
#  Model:                            OLS   Adj. R-squared:                 -0.008
#  Method:                 Least Squares   F-statistic:                    0.5106
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.478
#  Time:                        10:19:54   Log-Likelihood:                 43.339
#  No. Observations:                  60   AIC:                            -82.68
#  Df Residuals:                      58   BIC:                            -78.49
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4395      0.060      7.310      0.000       0.319       0.560
#  IT_lag4        0.0789      0.110      0.715      0.478      -0.142       0.300
#  ==============================================================================
#  Omnibus:                        4.408   Durbin-Watson:                   1.577
#  Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.427
#  Skew:                           0.524   Prob(JB):                        0.180
#  Kurtosis:                       3.523   Cond. No.                         9.17
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_OR~IT_lag5': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.001
#  Model:                            OLS   Adj. R-squared:                 -0.020
#  Method:                 Least Squares   F-statistic:                   0.05200
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.821
#  Time:                        10:19:54   Log-Likelihood:                 37.679
#  No. Observations:                  50   AIC:                            -71.36
#  Df Residuals:                      48   BIC:                            -67.53
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4990      0.062      8.005      0.000       0.374       0.624
#  IT_lag5       -0.0259      0.114     -0.228      0.821      -0.254       0.202
#  ==============================================================================
#  Omnibus:                        4.603   Durbin-Watson:                   1.201
#  Prob(Omnibus):                  0.100   Jarque-Bera (JB):                3.540
#  Skew:                           0.610   Prob(JB):                        0.170
#  Kurtosis:                       3.459   Cond. No.                         8.88
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_OR~IT_lag1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.040
#  Model:                            OLS   Adj. R-squared:                  0.029
#  Method:                 Least Squares   F-statistic:                     3.623
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0602
#  Time:                        10:19:54   Log-Likelihood:                 106.86
#  No. Observations:                  90   AIC:                            -209.7
#  Df Residuals:                      88   BIC:                            -204.7
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4385      0.039     11.227      0.000       0.361       0.516
#  IT_lag1        0.1303      0.068      1.904      0.060      -0.006       0.266
#  ==============================================================================
#  Omnibus:                        0.630   Durbin-Watson:                   1.595
#  Prob(Omnibus):                  0.730   Jarque-Bera (JB):                0.264
#  Skew:                           0.101   Prob(JB):                        0.876
#  Kurtosis:                       3.172   Cond. No.                         11.4
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_OR~IT_lag2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.001
#  Model:                            OLS   Adj. R-squared:                 -0.011
#  Method:                 Least Squares   F-statistic:                    0.1062
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.745
#  Time:                        10:19:54   Log-Likelihood:                 95.190
#  No. Observations:                  80   AIC:                            -186.4
#  Df Residuals:                      78   BIC:                            -181.6
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.5043      0.041     12.295      0.000       0.423       0.586
#  IT_lag2        0.0234      0.072      0.326      0.745      -0.120       0.167
#  ==============================================================================
#  Omnibus:                        0.115   Durbin-Watson:                   1.624
#  Prob(Omnibus):                  0.944   Jarque-Bera (JB):                0.284
#  Skew:                           0.057   Prob(JB):                        0.868
#  Kurtosis:                       2.732   Cond. No.                         11.3
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_OR~IT_lag3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.041
#  Model:                            OLS   Adj. R-squared:                  0.027
#  Method:                 Least Squares   F-statistic:                     2.942
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0909
#  Time:                        10:19:54   Log-Likelihood:                 89.688
#  No. Observations:                  70   AIC:                            -175.4
#  Df Residuals:                      68   BIC:                            -170.9
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4516      0.040     11.311      0.000       0.372       0.531
#  IT_lag3        0.1192      0.069      1.715      0.091      -0.019       0.258
#  ==============================================================================
#  Omnibus:                        0.204   Durbin-Watson:                   1.835
#  Prob(Omnibus):                  0.903   Jarque-Bera (JB):                0.393
#  Skew:                           0.063   Prob(JB):                        0.822
#  Kurtosis:                       2.655   Cond. No.                         11.3
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_OR~IT_lag4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.003
#  Model:                            OLS   Adj. R-squared:                 -0.014
#  Method:                 Least Squares   F-statistic:                    0.1665
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.685
#  Time:                        10:19:54   Log-Likelihood:                 77.561
#  No. Observations:                  60   AIC:                            -151.1
#  Df Residuals:                      58   BIC:                            -146.9
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.5360      0.041     13.175      0.000       0.455       0.617
#  IT_lag4       -0.0289      0.071     -0.408      0.685      -0.171       0.113
#  ==============================================================================
#  Omnibus:                        0.177   Durbin-Watson:                   1.777
#  Prob(Omnibus):                  0.915   Jarque-Bera (JB):                0.352
#  Skew:                          -0.093   Prob(JB):                        0.839
#  Kurtosis:                       2.674   Cond. No.                         10.7
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_OR~IT_lag5': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.020
#  Model:                            OLS   Adj. R-squared:                 -0.000
#  Method:                 Least Squares   F-statistic:                    0.9846
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.326
#  Time:                        10:19:54   Log-Likelihood:                 72.358
#  No. Observations:                  50   AIC:                            -140.7
#  Df Residuals:                      48   BIC:                            -136.9
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.4851      0.039     12.541      0.000       0.407       0.563
#  IT_lag5        0.0662      0.067      0.992      0.326      -0.068       0.200
#  ==============================================================================
#  Omnibus:                        0.239   Durbin-Watson:                   1.942
#  Prob(Omnibus):                  0.887   Jarque-Bera (JB):                0.103
#  Skew:                          -0.109   Prob(JB):                        0.950
#  Kurtosis:                       2.953   Cond. No.                         10.8
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_OR~IT_lag1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.128
#  Model:                            OLS   Adj. R-squared:                  0.118
#  Method:                 Least Squares   F-statistic:                     12.96
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):           0.000526
#  Time:                        10:19:54   Log-Likelihood:                 98.732
#  No. Observations:                  90   AIC:                            -193.5
#  Df Residuals:                      88   BIC:                            -188.5
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.2492      0.067      3.733      0.000       0.117       0.382
#  IT_lag1        0.4282      0.119      3.600      0.001       0.192       0.665
#  ==============================================================================
#  Omnibus:                        0.035   Durbin-Watson:                   1.163
#  Prob(Omnibus):                  0.982   Jarque-Bera (JB):                0.027
#  Skew:                          -0.019   Prob(JB):                        0.987
#  Kurtosis:                       2.925   Cond. No.                         18.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_OR~IT_lag2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.100
#  Model:                            OLS   Adj. R-squared:                  0.089
#  Method:                 Least Squares   F-statistic:                     8.698
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):            0.00420
#  Time:                        10:19:54   Log-Likelihood:                 87.501
#  No. Observations:                  80   AIC:                            -171.0
#  Df Residuals:                      78   BIC:                            -166.2
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.2888      0.070      4.138      0.000       0.150       0.428
#  IT_lag2        0.3669      0.124      2.949      0.004       0.119       0.615
#  ==============================================================================
#  Omnibus:                        0.610   Durbin-Watson:                   1.334
#  Prob(Omnibus):                  0.737   Jarque-Bera (JB):                0.712
#  Skew:                           0.060   Prob(JB):                        0.701
#  Kurtosis:                       2.553   Cond. No.                         17.8
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_OR~IT_lag3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.150
#  Model:                            OLS   Adj. R-squared:                  0.137
#  Method:                 Least Squares   F-statistic:                     11.97
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):           0.000940
#  Time:                        10:19:54   Log-Likelihood:                 80.872
#  No. Observations:                  70   AIC:                            -157.7
#  Df Residuals:                      68   BIC:                            -153.2
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.2574      0.069      3.744      0.000       0.120       0.395
#  IT_lag3        0.4241      0.123      3.459      0.001       0.179       0.669
#  ==============================================================================
#  Omnibus:                        0.278   Durbin-Watson:                   1.288
#  Prob(Omnibus):                  0.870   Jarque-Bera (JB):                0.021
#  Skew:                           0.002   Prob(JB):                        0.989
#  Kurtosis:                       3.085   Cond. No.                         17.4
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_OR~IT_lag4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.092
#  Model:                            OLS   Adj. R-squared:                  0.076
#  Method:                 Least Squares   F-statistic:                     5.844
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0188
#  Time:                        10:19:54   Log-Likelihood:                 68.512
#  No. Observations:                  60   AIC:                            -133.0
#  Df Residuals:                      58   BIC:                            -128.8
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.3173      0.075      4.202      0.000       0.166       0.468
#  IT_lag4        0.3259      0.135      2.417      0.019       0.056       0.596
#  ==============================================================================
#  Omnibus:                        1.256   Durbin-Watson:                   1.705
#  Prob(Omnibus):                  0.534   Jarque-Bera (JB):                0.581
#  Skew:                          -0.009   Prob(JB):                        0.748
#  Kurtosis:                       3.482   Cond. No.                         17.4
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_OR~IT_lag5': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                     OR   R-squared:                       0.039
#  Model:                            OLS   Adj. R-squared:                  0.019
#  Method:                 Least Squares   F-statistic:                     1.971
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.167
#  Time:                        10:19:54   Log-Likelihood:                 59.595
#  No. Observations:                  50   AIC:                            -115.2
#  Df Residuals:                      48   BIC:                            -111.4
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.3949      0.079      4.976      0.000       0.235       0.554
#  IT_lag5        0.1989      0.142      1.404      0.167      -0.086       0.484
#  ==============================================================================
#  Omnibus:                        0.069   Durbin-Watson:                   1.808
#  Prob(Omnibus):                  0.966   Jarque-Bera (JB):                0.070
#  Skew:                           0.060   Prob(JB):                        0.966
#  Kurtosis:                       2.861   Cond. No.                         17.5
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """}

# %%
def run_growth_regressions(df, label):
    results = {}

    # 執行回歸：OR_growth ~ IT_growth
    df_growth = df.dropna(subset=["IT_growth", "OR_growth"])
    model = smf.ols("OR_growth ~ IT_growth", data=df_growth).fit()

    results[f"{label}_ORgrowth~ITgrowth"] = model
    return results

# %%
# 成長率迴歸
report_7_results = run_growth_regressions(rename_columns(df_7_report), "Item7_report")
filter_7_results = run_growth_regressions(rename_columns(df_7_filter), "Item7_filter")
report_17_results = run_growth_regressions(
    rename_columns(df_17_report), "Item17_report"
)
filter_17_results = run_growth_regressions(
    rename_columns(df_17_filter), "Item17_filter"
)

# 顯示所有模型的 summary
all_models = {
    **report_7_results,
    **filter_7_results,
    **report_17_results,
    **filter_17_results,
}
model_summaries = {name: model.summary() for name, model in all_models.items()}
model_summaries
# Out:
# {'Item7_report_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.033
#  Model:                            OLS   Adj. R-squared:                  0.022
#  Method:                 Least Squares   F-statistic:                     3.012
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0862
#  Time:                        10:38:50   Log-Likelihood:                 20.203
#  No. Observations:                  90   AIC:                            -36.41
#  Df Residuals:                      88   BIC:                            -31.41
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0095      0.021      0.455      0.650      -0.032       0.051
#  IT_growth      0.1544      0.089      1.735      0.086      -0.022       0.331
#  ==============================================================================
#  Omnibus:                       20.347   Durbin-Watson:                   2.648
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.202
#  Skew:                           1.007   Prob(JB):                     4.56e-07
#  Kurtosis:                       4.932   Cond. No.                         4.32
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.016
#  Model:                            OLS   Adj. R-squared:                  0.005
#  Method:                 Least Squares   F-statistic:                     1.439
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.233
#  Time:                        10:38:50   Log-Likelihood:                -10.272
#  No. Observations:                  90   AIC:                             24.54
#  Df Residuals:                      88   BIC:                             29.54
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0139      0.029      0.478      0.634      -0.044       0.072
#  IT_growth      0.1458      0.122      1.200      0.233      -0.096       0.387
#  ==============================================================================
#  Omnibus:                        3.567   Durbin-Watson:                   2.676
#  Prob(Omnibus):                  0.168   Jarque-Bera (JB):                3.199
#  Skew:                           0.461   Prob(JB):                        0.202
#  Kurtosis:                       3.044   Cond. No.                         4.21
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.001
#  Model:                            OLS   Adj. R-squared:                 -0.011
#  Method:                 Least Squares   F-statistic:                   0.06603
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.798
#  Time:                        10:38:50   Log-Likelihood:                 30.678
#  No. Observations:                  90   AIC:                            -57.36
#  Df Residuals:                      88   BIC:                            -52.36
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0195      0.018      1.060      0.292      -0.017       0.056
#  IT_growth     -0.0177      0.069     -0.257      0.798      -0.155       0.119
#  ==============================================================================
#  Omnibus:                        2.943   Durbin-Watson:                   3.016
#  Prob(Omnibus):                  0.230   Jarque-Bera (JB):                2.625
#  Skew:                           0.418   Prob(JB):                        0.269
#  Kurtosis:                       3.007   Cond. No.                         3.77
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.047
#  Model:                            OLS   Adj. R-squared:                  0.036
#  Method:                 Least Squares   F-statistic:                     4.361
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0397
#  Time:                        10:38:50   Log-Likelihood:                 32.937
#  No. Observations:                  90   AIC:                            -61.87
#  Df Residuals:                      88   BIC:                            -56.87
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0154      0.018      0.860      0.392      -0.020       0.051
#  IT_growth      0.3234      0.155      2.088      0.040       0.016       0.631
#  ==============================================================================
#  Omnibus:                        9.237   Durbin-Watson:                   2.384
#  Prob(Omnibus):                  0.010   Jarque-Bera (JB):               12.514
#  Skew:                           0.459   Prob(JB):                      0.00192
#  Kurtosis:                       4.579   Cond. No.                         8.66
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """}

# %%
# 成長率時間遞移迴歸
report_7_results = run_growth_regressions(rename_columns(df_7_report), "Item7_report")
filter_7_results = run_growth_regressions(rename_columns(df_7_filter), "Item7_filter")
report_17_results = run_growth_regressions(
    rename_columns(df_17_report), "Item17_report"
)
filter_17_results = run_growth_regressions(
    rename_columns(df_17_filter), "Item17_filter"
)

# 顯示所有模型的 summary
all_models = {
    **report_7_results,
    **filter_7_results,
    **report_17_results,
    **filter_17_results,
}
model_summaries = {name: model.summary() for name, model in all_models.items()}
model_summaries
# Out:
# {'Item7_report_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.033
#  Model:                            OLS   Adj. R-squared:                  0.022
#  Method:                 Least Squares   F-statistic:                     3.012
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0862
#  Time:                        10:19:58   Log-Likelihood:                 20.203
#  No. Observations:                  90   AIC:                            -36.41
#  Df Residuals:                      88   BIC:                            -31.41
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0095      0.021      0.455      0.650      -0.032       0.051
#  IT_growth      0.1544      0.089      1.735      0.086      -0.022       0.331
#  ==============================================================================
#  Omnibus:                       20.347   Durbin-Watson:                   2.648
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.202
#  Skew:                           1.007   Prob(JB):                     4.56e-07
#  Kurtosis:                       4.932   Cond. No.                         4.32
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item7_filter_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.016
#  Model:                            OLS   Adj. R-squared:                  0.005
#  Method:                 Least Squares   F-statistic:                     1.439
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.233
#  Time:                        10:19:58   Log-Likelihood:                -10.272
#  No. Observations:                  90   AIC:                             24.54
#  Df Residuals:                      88   BIC:                             29.54
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0139      0.029      0.478      0.634      -0.044       0.072
#  IT_growth      0.1458      0.122      1.200      0.233      -0.096       0.387
#  ==============================================================================
#  Omnibus:                        3.567   Durbin-Watson:                   2.676
#  Prob(Omnibus):                  0.168   Jarque-Bera (JB):                3.199
#  Skew:                           0.461   Prob(JB):                        0.202
#  Kurtosis:                       3.044   Cond. No.                         4.21
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_report_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.001
#  Model:                            OLS   Adj. R-squared:                 -0.011
#  Method:                 Least Squares   F-statistic:                   0.06603
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):              0.798
#  Time:                        10:19:58   Log-Likelihood:                 30.678
#  No. Observations:                  90   AIC:                            -57.36
#  Df Residuals:                      88   BIC:                            -52.36
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0195      0.018      1.060      0.292      -0.017       0.056
#  IT_growth     -0.0177      0.069     -0.257      0.798      -0.155       0.119
#  ==============================================================================
#  Omnibus:                        2.943   Durbin-Watson:                   3.016
#  Prob(Omnibus):                  0.230   Jarque-Bera (JB):                2.625
#  Skew:                           0.418   Prob(JB):                        0.269
#  Kurtosis:                       3.007   Cond. No.                         3.77
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'Item17_filter_ORgrowth~ITgrowth': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:              OR_growth   R-squared:                       0.047
#  Model:                            OLS   Adj. R-squared:                  0.036
#  Method:                 Least Squares   F-statistic:                     4.361
#  Date:                Wed, 16 Apr 2025   Prob (F-statistic):             0.0397
#  Time:                        10:19:58   Log-Likelihood:                 32.937
#  No. Observations:                  90   AIC:                            -61.87
#  Df Residuals:                      88   BIC:                            -56.87
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  Intercept      0.0154      0.018      0.860      0.392      -0.020       0.051
#  IT_growth      0.3234      0.155      2.088      0.040       0.016       0.631
#  ==============================================================================
#  Omnibus:                        9.237   Durbin-Watson:                   2.384
#  Prob(Omnibus):                  0.010   Jarque-Bera (JB):               12.514
#  Skew:                           0.459   Prob(JB):                      0.00192
#  Kurtosis:                       4.579   Cond. No.                         8.66
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """}
